# %% [markdown]
#  # Autor
#
# Nombre: Ricardo Arévalo Hernández
#
# GitHub: Arévalo Hdez
#
# -----------

# %% [markdown]
# # 1.

# %% [markdown]
# Importe `matplotlib.pyplot` y `numpy` con sus respectivos alías.

# %%
import matplotlib.pyplot as plt # Paquete de graficos.
import numpy as np              # Computó Numérico.

# %% [markdown]
# # 2.
# Escriba una función que se llame `A_sin()` que reciba como parámetro a `t` y argumentos `A = 1`, `omega = 2*np.pi` y `phi = np.pi/2` y que regrese $f(t) = A\sin(t\omega_0 + \phi )$. Nota: La función debe conntar con un *docstring*. En las celdas a continucación se muestra el funcionamiento de `A_sin()`

# %%
def A_sin(t, A = 1, omega = 2*np.pi, phi = np.pi/2):  
    """"Esta función regresara un valor dependiendo de los valores que les des """
    
    return A*np.sin(t*omega + phi)

# %%
print(A_sin.__doc__)
# Out:
# "Esta función regresara un valor dependiendo de los valores que les des

# %% [raw]
# ?A_sin

# %%
A_sin(0)
# Out:
# 1.0

# %%
A_sin(0, A = 2)
# Out:
# 2.0

# %%
A_sin(0.5, A = 2)
# Out:
# -2.0

# %%
A_sin(0.5, omega = np.pi)
# Out:
# 1.2246467991473532e-16

# %%
A_sin(0.0, phi = np.pi)
# Out:
# 1.2246467991473532e-16

# %%
A_sin(0.5, A = 2, omega = np.pi/2, phi = np.pi)
# Out:
# -1.414213562373095

# %% [markdown]
# # 3.
#
# Escriba un ***ciclo*** que grafique la función $f:[-\pi , \pi]\longrightarrow \mathbb{R}$ tal que $f(t) = A\sin(t\omega_0 + \phi )$, que es la función que se implemento en el ejercicio 2.
#
# * ***Donde $A$ debe de tomar los siguientes valores $[0,0.5,1,1.5,2.0, 2.5]$ y el resto de los argumetos se tomará por defecto de la definición de `A_sin()`***
# * ***Donde $\omega$ debe de tomar los siguientes valores $\left[0,\frac{\pi}{2}, \pi, \frac{3\pi}{2},2\pi, \frac{5\pi}{2} \right]$ y el resto de los argumetos se tomará por defecto de la definición de `A_sin()`***
# * ***Donde $\phi$ debe de tomar los siguientes valores $\left[-2\pi,-\frac{3\pi}{2},-\pi,-\frac{\pi}{2}, 0,\frac{\pi}{2}, \pi, \frac{3\pi}{2},2\pi \right]$ y el resto de los argumetos se tomará por defecto de la definición de `A_sin()`***

# %% [markdown]
# ***A continuación se muestra un ejemplo de que se espera***

# %%
t = np.linspace(-np.pi, np.pi, 200)

# %%
print(t)
# Out:
# [-3.14159265 -3.11001886 -3.07844506 -3.04687127 -3.01529747 -2.98372368
#  -2.95214988 -2.92057608 -2.88900229 -2.85742849 -2.8258547  -2.7942809
#  -2.76270711 -2.73113331 -2.69955952 -2.66798572 -2.63641193 -2.60483813
#  -2.57326433 -2.54169054 -2.51011674 -2.47854295 -2.44696915 -2.41539536
#  -2.38382156 -2.35224777 -2.32067397 -2.28910017 -2.25752638 -2.22595258
#  -2.19437879 -2.16280499 -2.1312312  -2.0996574  -2.06808361 -2.03650981
#  -2.00493602 -1.97336222 -1.94178842 -1.91021463 -1.87864083 -1.84706704
#  -1.81549324 -1.78391945 -1.75234565 -1.72077186 -1.68919806 -1.65762426
#  -1.62605047 -1.59447667 -1.56290288 -1.53132908 -1.49975529 -1.46818149
#  -1.4366077  -1.4050339  -1.3734601  -1.34188631 -1.31031251 -1.27873872
#  -1.24716492 -1.21559113 -1.18401733 -1.15244354 -1.12086974 -1.08929595
#  -1.05772215 -1.02614835 -0.99457456 -0.96300076 -0.93142697 -0.89985317
#  -0.86827938 -0.83670558 -0.80513179 -0.77355799 -0.74198419 -0.7104104
#  -0.6788366  -0.64726281 -0.61568901 -0.58411522 -0.55254142 -0.52096763
#  -0.48939383 -0.45782003 -0.42624624 -0.39467244 -0.36309865 -0.33152485
#  -0.29995106 -0.26837726 -0.23680347 -0.20522967 -0.17365588 -0.14208208
#  -0.11050828 -0.07893449 -0.04736069 -0.0157869   0.0157869   0.04736069
#   0.07893449  0.11050828  0.14208208  0.17365588  0.20522967  0.23680347
#   0.26837726  0.29995106  0.33152485  0.36309865  0.39467244  0.42624624
#   0.45782003  0.48939383  0.52096763  0.55254142  0.58411522  0.61568901
#   0.64726281  0.6788366   0.7104104   0.74198419  0.77355799  0.80513179
#   0.83670558  0.86827938  0.89985317  0.93142697  0.96300076  0.99457456
#   1.02614835  1.05772215  1.08929595  1.12086974  1.15244354  1.18401733
#   1.21559113  1.24716492  1.27873872  1.31031251  1.34188631  1.3734601
#   1.4050339   1.4366077   1.46818149  1.49975529  1.53132908  1.56290288
#   1.59447667  1.62605047  1.65762426  1.68919806  1.72077186  1.75234565
#   1.78391945  1.81549324  1.84706704  1.87864083  1.91021463  1.94178842
#   1.97336222  2.00493602  2.03650981  2.06808361  2.0996574   2.1312312
#   2.16280499  2.19437879  2.22595258  2.25752638  2.28910017  2.32067397
#   2.35224777  2.38382156  2.41539536  2.44696915  2.47854295  2.51011674
#   2.54169054  2.57326433  2.60483813  2.63641193  2.66798572  2.69955952
#   2.73113331  2.76270711  2.7942809   2.8258547   2.85742849  2.88900229
#   2.92057608  2.95214988  2.98372368  3.01529747  3.04687127  3.07844506
#   3.11001886  3.14159265]

# %%
A = np.linspace(0, 2.5, 6)

# %%
print(A)
# Out:
# [0.  0.5 1.  1.5 2.  2.5]

# %%
omega = np.linspace(0, 5*np.pi/2, 5)

# %%
print(omega)
# Out:
# [0.         1.96349541 3.92699082 5.89048623 7.85398163]

# %%
phi = np.linspace(-2*np.pi, 2*np.pi, 9)

# %%
print(phi)
# Out:
# [-6.28318531 -4.71238898 -3.14159265 -1.57079633  0.          1.57079633
#   3.14159265  4.71238898  6.28318531]

# %%
j = 0
while j <= 2.5:
    
    plt.plot(t, A_sin(t, A = j), label = f"A = {j}")
    j = j + 0.5
    
plt.legend()
plt.grid()
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], ["$-\pi$", "$-\pi/2$", "0", "$\pi/2$", "$\pi$"], color="b")
plt.yticks([-2.5,-2, -1, 0, 1, 2, 2.5], ["$-2.5$", "$-2$", "$-1$", "$0$", "$1$", "$2$", "$2.5$"], color="b")
plt.ylabel("$f(x)$", rotation = 0, color = "b")
plt.xlabel("$x$", rotation = 0, color = "b")
# Out:
# Text(0.5, 0, '$x$')

# %% [markdown]
# Donde 𝜔 debe de tomar los siguientes valores [0, 𝜋2, 𝜋, 3𝜋2, 2𝜋, 5𝜋2] y el resto de los argumetos se tomará por defecto de la definición de

# %%
j = 0
while j <= 5*np.pi/2:
    
    plt.plot(t, A_sin(t, omega = j), label = f"omega = {j}")
    j = j + np.pi/2
    
plt.legend()
plt.ylabel("$f(x)$", rotation = 0, color = "r")
plt.xlabel("$x$", rotation = 0, color = "r")
# Out:
# Text(0.5, 0, '$x$')

# %% [markdown]
# # 4.

# %% [markdown]
# Una función que cuenta con infinitas derivadas y además estás son continuas, se puede escribir como la siguiente serie alrededor de un punto $x_0$ del dominio de la función:
#
# $$f(x) = \displaystyle \sum_{k = 0}^{\infty}\dfrac{f^{k}(x_0)}{k!}(x - x_0)^k$$
#
# Donde $f^{n}(x_0)$ denota la n-ésima derivada de la función $f$ evaluada en $x_0$. Sin embargo podemos aproximar a la función $f$ truncando la serie a un cierto orden $n$ y lo que nos queda es un polinomio de orden $n$, a continuación se muestran algunas aproximaciones de ciertas funciones:
#
# * $\exp(x)  \approx \displaystyle \sum_{k = 0}^{n}\dfrac{x^k}{k!}$
#
# * $\ln(1- x)  \approx - \displaystyle \sum_{k = 0}^{n}\dfrac{x^k}{k}$
#
# * $\sin(x)  \approx \displaystyle \sum_{k = 0}^{n}\dfrac{(-1)^k}{(2k +1)!}x^{2k+1}$
#
#
# * $\cos(x)  \approx \displaystyle \sum_{k = 0}^{n}\dfrac{(-1)^k}{(2k )!}x^{2k}$
#
# Implemente cuatro funciones cuyos nombres sean: `my_exp()`, `my_ln()`, `my_sin()` y `my_cos()` que aproximen las respectivas funciones a un orden $n$ alrededor de un punto $x_0$. Por ejemplo:

# %%
def my_factorial(n):
    """"La función calcula el factorial de un número cualquiera"""
    x = 1
    
    for i in range(1, n + 1):
        x += i
    return x

# %%
my_factorial(5)
# Out:
# 16

# %%
def my_exp(x, n = 8):
    k = 0 
    count = 0 
    while k < n: 
        count = count + (x**k)/my_factorial(k)
        k += 1
    return count

# %%
my_exp(np.pi/2, 3)
# Out:
# 3.8044968769310663

# %%
def my_ln(x, n = 10):
    k = 0 
    count = 0 
    while k < n: 
        count = count - (x**k)/my_factorial(k)
        k += 1
    return count

# %%
my_ln(np.pi/2, 3)
# Out:
# -3.8044968769310663

# %%
def my_cos(x, n = 10):
    k = 0 
    count = 0 
    while k < n: 
        count = count + (((-1)**k)*(x**(2*k)))/my_factorial(2*k)
        k += 1
    return count

# %%
my_cos(np.pi/3, 3)
# Out:
# 0.501796201500181

# %%
def my_sin(x, n = 10):
    
    k = 0
    count = 0
    while k < n:
        count = count + (((-1)**k)*(x**(2*k + 1)))/my_factorial(2*k + 1)
        k += 1
    return count

# %%
my_sin(np.pi/2, 3)
# Out:
# 1.0045248555348174

# %% [markdown]
# En la celda anterior se está evaluando la función seno en $\frac{\pi}{2}$ a orden $3$, y observe que calcula una aproximación al $\sin(\frac{\pi}{2})$ que es $1$.

# %%
my_sin(np.pi/2, 9)
# Out:
# 1.0000000000000437

# %% [markdown]
# En la celda anterior se está evaluando la función seno en $\frac{\pi}{2}$ a orden $9$. Y está aproximación en mucho mejor que en el caso anterior

# %%
my_sin(np.pi/2, 16)
# Out:
# 1.0000000000000002

# %% [markdown]
# ***Notas:***
#
# * ***Antes de implementar las funciones de este ejercicio debe de implentar el factorial de un número ya que va a utilizar***
#
# * ***Las funciones deben de estar bien documentadas***

# %% [markdown]
# # 5.

# %% [markdown]
# * ***Cree un `array` cuya variable sea `x` que comiencé en $-\pi$ termine en $\pi$ y tenga $101$ puntos.***
#
# * ***Grafiqué `exp(x, 8)`***
#
# * ***Realice lo mismo para las funciones del ejercicio anterior***
#
# * ***mediante un ciclo parecido al ejercicio 2, grafique la funcion, `my_exp()`, alrededor del cero a distintos orden***
# * ***Realice lo mismo para las funciones del ejercicio anterior***
#
# * ***¿Que puede concluir de este tipo de aproximación?***
#
# * ***Si usted quisiera implementar una calculadora como calcularía el $\tan(\pi)$***

# %% [markdown]
# Ejemplo de la gráfica que se espera para el seno

# %%
x = np.linspace(-np.pi, np.pi, 101)

# %%
print(x)
# Out:
# [-3.14159265e+00 -3.07876080e+00 -3.01592895e+00 -2.95309709e+00
#  -2.89026524e+00 -2.82743339e+00 -2.76460154e+00 -2.70176968e+00
#  -2.63893783e+00 -2.57610598e+00 -2.51327412e+00 -2.45044227e+00
#  -2.38761042e+00 -2.32477856e+00 -2.26194671e+00 -2.19911486e+00
#  -2.13628300e+00 -2.07345115e+00 -2.01061930e+00 -1.94778745e+00
#  -1.88495559e+00 -1.82212374e+00 -1.75929189e+00 -1.69646003e+00
#  -1.63362818e+00 -1.57079633e+00 -1.50796447e+00 -1.44513262e+00
#  -1.38230077e+00 -1.31946891e+00 -1.25663706e+00 -1.19380521e+00
#  -1.13097336e+00 -1.06814150e+00 -1.00530965e+00 -9.42477796e-01
#  -8.79645943e-01 -8.16814090e-01 -7.53982237e-01 -6.91150384e-01
#  -6.28318531e-01 -5.65486678e-01 -5.02654825e-01 -4.39822972e-01
#  -3.76991118e-01 -3.14159265e-01 -2.51327412e-01 -1.88495559e-01
#  -1.25663706e-01 -6.28318531e-02  4.44089210e-16  6.28318531e-02
#   1.25663706e-01  1.88495559e-01  2.51327412e-01  3.14159265e-01
#   3.76991118e-01  4.39822972e-01  5.02654825e-01  5.65486678e-01
#   6.28318531e-01  6.91150384e-01  7.53982237e-01  8.16814090e-01
#   8.79645943e-01  9.42477796e-01  1.00530965e+00  1.06814150e+00
#   1.13097336e+00  1.19380521e+00  1.25663706e+00  1.31946891e+00
#   1.38230077e+00  1.44513262e+00  1.50796447e+00  1.57079633e+00
#   1.63362818e+00  1.69646003e+00  1.75929189e+00  1.82212374e+00
#   1.88495559e+00  1.94778745e+00  2.01061930e+00  2.07345115e+00
#   2.13628300e+00  2.19911486e+00  2.26194671e+00  2.32477856e+00
#   2.38761042e+00  2.45044227e+00  2.51327412e+00  2.57610598e+00
#   2.63893783e+00  2.70176968e+00  2.76460154e+00  2.82743339e+00
#   2.89026524e+00  2.95309709e+00  3.01592895e+00  3.07876080e+00
#   3.14159265e+00]

# %%
def my_exp(x, n = 8):
    k = 0 
    count = 0 
    while k < n: 
        count = count + (x**k)/my_factorial(k)
        k += 1
    return count
